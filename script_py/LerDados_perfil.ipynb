# %% [markdown]
# ![Captura%20de%20Tela%202021-03-23%20a%CC%80s%2013.19.20.png](attachment:Captura%20de%20Tela%202021-03-23%20a%CC%80s%2013.19.20.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from pathlib import Path
from math import *

# %%
# workDir = Path.home()
# str(workDir)
workDir= '/Users/sabrinabms/Documents/GitHub/mpcaRNA_perfil/data/'

# %%
print(os.listdir(workDir))
# Out:
# ['y_gen.txt', 'x_gen.txt', 'saida_gen.txt', 'x.txt', 'y.txt', 'entrada_gen.txt', 'entrada.txt', 'y_valid.txt', 'x_valid.txt']

# %% [markdown]
# ### Arquivos entrada --> RNA

# %%
x = pd.read_csv(workDir+'x.txt', "r", header=None, delimiter=r"\s+")

# %%
x_valid = pd.read_csv(workDir+'x_valid.txt', "r", header=None, delimiter=r"\s+")

# %%
x_gen = pd.read_csv(workDir+'x_gen.txt', "r", header=None, delimiter=r"\s+")

# %%
x.shape, x_valid.shape, x_gen.shape
# Out:
# ((7, 250), (7, 50), (7, 346))

# %%
x.head(3)
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.147448  0.142500  0.152224  0.128723  0.131402  0.133382  0.128556
# 1  0.101961  0.101267  0.100266  0.088226  0.100803  0.088359  0.089270
# 2  0.094526  0.094333  0.093671  0.085572  0.098659  0.083419  0.085264
#
#         7         8         9    ...       240       241       242       243  \
# 0  0.133193  0.131385  0.126313  ...  0.137770  0.147731  0.132865  0.124462
# 1  0.098696  0.097004  0.085897  ...  0.096602  0.108937  0.086330  0.089578
# 2  0.096370  0.093756  0.083252  ...  0.087207  0.098645  0.081693  0.090820
#
#         244       245       246       247       248       249
# 0  0.144379  0.134392  0.140483  0.142891  0.149737  0.152246
# 1  0.097179  0.111104  0.103502  0.104784  0.113101  0.112535
# 2  0.090164  0.110691  0.096113  0.098458  0.105282  0.105621
#
# [3 rows x 250 columns]

# %% [markdown]
# ### Arquivos saida --> RNA

# %%
yd = pd.read_csv(workDir+'y.txt', "r", header=None, delimiter=r"\s+")

# %%
yd_valid = pd.read_csv(workDir+'y_valid.txt', "r", header=None, delimiter=r"\s+")

# %%
yd_gen = pd.read_csv(workDir+'y_gen.txt', "r", header=None, delimiter=r"\s+")

# %%
yd.shape, yd_valid.shape, yd_gen.shape
# Out:
# ((40, 250), (40, 50), (40, 346))

# %%
yd.head(3)
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.336286  0.348611  0.365056  0.278813  0.311155  0.327222  0.265630
# 1  0.364507  0.374155  0.386961  0.321214  0.341642  0.357812  0.310880
# 2  0.399767  0.406015  0.415182  0.370653  0.377038  0.392969  0.363546
#
#         7         8         9    ...       240       241       242       243  \
# 0  0.267381  0.294435  0.320012  ...  0.308168  0.263879  0.335874  0.291551
# 1  0.311738  0.331273  0.352010  ...  0.343873  0.307550  0.366464  0.331960
# 2  0.364335  0.374807  0.388403  ...  0.385519  0.360456  0.400419  0.381090
#
#         244       245       246       247       248       249
# 0  0.325403  0.301782  0.336835  0.248395  0.276136  0.298177
# 1  0.359186  0.330106  0.363134  0.299379  0.317815  0.338415
# 2  0.398840  0.360113  0.396162  0.362516  0.368833  0.387922
#
# [3 rows x 250 columns]

# %% [markdown]
# ### Resultado obtido

# %%
resultado = pd.read_csv(workDir+'saida_gen.txt', "r", header=None, delimiter=r"\s+")

# %% [markdown]
# ### Resultado apresentado no artigo

# %% [markdown]
# ![Captura%20de%20Tela%202021-03-23%20a%CC%80s%2015.16.02.png](attachment:Captura%20de%20Tela%202021-03-23%20a%CC%80s%2015.16.02.png)

# %%
verdade = yd_gen.loc[:,1]
saida = resultado.loc[:,1]
niveis = range(40)

# %%
fig, ax = plt.subplots(figsize=(5,10))
ax.plot(verdade[::-1],niveis, marker = '*',label = "verdade")
ax.plot(saida[::-1], niveis, marker = '.',label="saida RNA")
ax.set(title = "Perfil de temperatura")
plt.show()
